# %%
import numpy as np
import gzip
import pickle
import sys
import copy
import os.path
from copy import deepcopy

import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# # Perm Cl1

# %%
with open('../../DEN/den_perm_cl1_t5.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
# Out:
# dict_keys(['accs', 'uncerts'])

# %%
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

# %%
print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))
# Out:
# Overall accs: 0.908 pm 0.010
# /nfs/home/samuelk/anaconda2/envs/tf-gpu-cuda8/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1666: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)

# %%
from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()

# %%
with open('../../DEN/den_perm_cl1_t5_50_n5_thr010_sthr010_l01.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))
print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.914 pm 0.005

# %%
with open('../../DEN/den_perm_cl1_t5_50_n5_thr010_sthr010_l01_disable_ts_inf.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))
from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.916 pm 0.005

# %% [markdown]
# ## CL3

# %%
with open('../../DEN/den_perm_cl3_t5.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
# Out:
# dict_keys(['accs', 'uncerts'])

# %%
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

# %%
print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))
# Out:
# Overall accs: 0.683 pm 0.201

# %%
from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()

# %%
with open('../../DEN/den_perm_cl3_t5_50_n5_thr010_sthr010_l01.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))
from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.639 pm 0.192

# %%
with open('../../DEN/den_perm_cl3_t5_50_n5_thr010_sthr010_l01_disable_ts_inf.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))
from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.751 pm 0.210

# %% [markdown]
# # Perm t10

# %%
with open('../../DEN/den_perm_cl1_t10.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))
print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))
# Out:
# Overall accs: 0.929 pm 0.004

# %%
from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()

# %%
with open('../../DEN/den_perm_cl1_t10_50_n5_thr010_sthr010_l01.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))
print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))
from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.904 pm 0.006

# %%
with open('../../DEN/den_perm_cl3_t10_50_n5_thr010_sthr010_l01.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))
print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))
# Out:
# Overall accs: 0.373 pm 0.138

# %% [markdown]
# # Split CL1

# %%
with open('../../DEN/den_split_cl1_t5.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

# %%
print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.992 pm 0.001

# %%
with open('../../DEN/den_split_cl1_t5_50_n5_thr010_sthr010_l01.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))
print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.991 pm 0.001

# %%
with open('../../DEN/den_split_cl1_t5_50_n5_thr010_sthr010_l01_disable_ts_inf.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))
print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.988 pm 0.001

# %% [markdown]
# ## Split CL2

# %%
with open('../../DEN/den_split_cl2_t5.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

# %%
print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.991 pm 0.001

# %%
with open('../../DEN/den_split_cl2_t5_50_n5_thr005.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))
print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.992 pm 0.001

# %%
with open('../../DEN/den_split_cl2_t5_5_n5_thr010.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))
print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.988 pm 0.001

# %%
with open('../../DEN/den_split_cl2_t5_5_n5_thr010_sthr010_l01.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))
print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.989 pm 0.001

# %%
with open('../../DEN/den_split_cl2_t5_50_n5_thr010_sthr010_l01_disable_ts_inf.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))
print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.989 pm 0.001

# %% [markdown]
# ## Split CL3

# %%
with open('../../DEN/den_split_cl3_t5.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

# %%
print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.991 pm 0.001

# %%
with open('../../DEN/den_split_cl3_t5_50_n5_thr010_sthr010_l01.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))
print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.991 pm 0.001

# %%
with open('../../DEN/den_split_cl3_t5_50_n5_thr010_sthr010_l01_disable_ts_inf.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))
print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.936 pm 0.104

# %% [markdown]
# # Split random cl1

# %%
with open('../../DEN/den_split_random_cl1_t5.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.973 pm 0.001

# %%
with open('../../DEN/den_split_random_cl1_t5_50.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.974 pm 0.001

# %%
with open('../../DEN/den_split_random_cl1_t550_n5_thr010_sthr010_l01.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.972 pm 0.002

# %%
with open('../../DEN/den_split_random_cl1_t550_n5_thr010_sthr010_l01_disable_ts_inf.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.951 pm 0.019

# %% [markdown]
# ## Split ranodm cl2

# %%
with open('../../DEN/den_split_random_cl1_t5.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formaatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.973 pm 0.001

# %%
with open('../../DEN/den_split_random_cl2_t5_50_n5_thr005.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    #ax[i].yaxis.set_major_formaatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.973 pm 0.001

# %%
with open('../../DEN/den_split_random_cl2_t5_5_n5_thr010.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    #ax[i].yaxis.set_major_formaatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.952 pm 0.041

# %%
with open('../../DEN/den_split_random_cl2_t5_5_n5_thr010_sthr010_l01.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    #ax[i].yaxis.set_major_formaatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.848 pm 0.166

# %%
with open('../../DEN/den_split_random_cl2_t5_50_n5_thr010_sthr010_l01_disable_ts_inf.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    #ax[i].yaxis.set_major_formaatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.911 pm 0.070

# %% [markdown]
# ## split random cl3

# %%
with open('../../DEN/den_split_random_cl3_t5.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.932 pm 0.081

# %%
with open('../../DEN/den_split_random_cl3_t5_50_n5_thr010_sthr010_l01.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.909 pm 0.127

# %%
with open('../../DEN/den_split_random_cl3_t5_50_n5_thr010_sthr010_l01_disable_ts_inf.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.541 pm 0.241

# %% [markdown]
# ## split images cl1

# %%
with open('../../DEN/den_split_images_cl1_t5_50.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.944 pm 0.002

# %%
with open('../../DEN/den_split_images_cl1_t5_50_n5_thr010_sthr010_l01.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.938 pm 0.008

# %%
with open('../../DEN/den_split_images_cl1_t5_50_n5_thr010_sthr010_l01_disable_ts_inf.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.917 pm 0.021

# %%
with open('../../DEN/den_split_images_cl2_t5.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.944 pm 0.002

# %%
with open('../../DEN/den_split_images_cl2_t5_50_n5_thr005.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.918 pm 0.050

# %%
with open('../../DEN/den_split_images_cl2_t5_5_n5_thr010.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.869 pm 0.092

# %%
with open('../../DEN/den_split_images_cl2_t5_5_n5_thr010_sthr010_l01.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')q
fig.show()
# Out:
# Overall accs: 0.791 pm 0.131

# %%
with open('../../DEN/den_split_cl2_t5_50_n5_thr010_sthr010_l01_disable_ts_inf.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')q
fig.show()
# Out:
# Overall accs: 0.989 pm 0.001

# %%
with open('../../DEN/den_split_images_cl3_t5.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.811 pm 0.123

# %%
with open('../../DEN/den_split_images_cl3_t5_50_n5_thr010_sthr010_l01.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.916 pm 0.051

# %%
with open('../../DEN/den_split_images_cl3_t5_50_n5_thr010_sthr010_l01_disable_ts_inf.pkl', 'rb') as input_file:
    d = pickle.load(input_file)
d.keys()
accs = d['accs']
acc = np.mean(accs, 0)
__acc = np.nanmean(accs, (0,1))

print("Overall accs: {0:.3f} pm {1:.3f}".format(np.nanmean(accs), np.nanmean(np.nanstd(accs, 0))))

from matplotlib.ticker import FormatStrFormatter
lw = 2
grid_color = '0.1'
grid_lw = 0.2
title_size = 16
label_size = 22
tick_size = 14
legend_size = 16
no_tasks=5
fig, ax = plt.subplots(1, 6, figsize=(22, 3))
for i in range(no_tasks):
    ax[i].plot(np.arange(len(acc[:, i]))+1, acc[:, i], label='DEN', marker='o', linewidth=lw)
    ax[i].set_xticks(range(1, len(acc[:,i])+1))
    ax[i].set_xlabel('Tasks seen', fontsize=legend_size)
    ax[i].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax[i].tick_params(labelsize=tick_size)
    if i == 5:
        ax[i].legend(fontsize=legend_size)
    if i == 0:
        ax[i].set_ylabel('Accuracy', fontsize=legend_size)
ax[5].plot(np.arange(len(__acc))+1, __acc, label='DEN', marker='o', linewidth=lw)
ax[5].set_xticks(range(1, len(__acc)+1))
ax[5].set_title('Average accuracy', fontsize=legend_size)
ax[5].set_xlabel('Task', fontsize=legend_size)
ax[5].tick_params(labelsize=tick_size)
ax[5].yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#ax[5].legend()
#plt.savefig("plots/accs_all_hibp_cifar_mh_l1.pdf", bbox_inches='tight')
fig.show()
# Out:
# Overall accs: 0.467 pm 0.143
